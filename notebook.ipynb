# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Datasets
# - Nama: Damar Satria Buana
# - Email: buanasatriaa@gmail.com
# - Id Dicoding: -

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pada musim apa biasanya orang lebih banyak melakukan sewa sepeda?
# - Bagaimana jumlah pengguna sepeda dari tahun 2011-2012?
# - Kondisi cuaca apa biasanya orang lebih banyak melakukan sewa sepeda?
# - Pada bulan apa pengguna paling banyak melakukan sewa sepeda di tahun 2011?
# - Pada bulan apa pengguna paling banyak melakukan sewa sepeda di tahun 2012?

# %% [markdown]
# ## Menyaipkan semua library yang dibuthkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# Dataframe day

# %%
day_df = pd.read_csv('bike_data/day.csv')
day_df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %% [markdown]
# Dataframe hour

# %%
hour_df = pd.read_csv('bike_data/hour.csv')
hour_df
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# Cek missing value day_df

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# Cek missing value hour_df

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# Cek duplikasi data day_df

# %%
day_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Cek duplikasi data hour_df

# %%
hour_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Cek keberadaan outlier menggunakan describe()

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hour_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Dataset di atas sudah bersih dari missing value, nilai duplikat, dan nilai outlier

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# ### Pertanyaan 1: Pada musim apa biasanya orang lebih banyak melakukan sewa sepeda?

# %%
# Mengelompokkan jumlah data pengguna berdasarkan season

group_by_season = day_df.groupby(by='season').agg({
    'casual': 'sum',
    'registered': 'sum',
    'total_rentals': 'sum',
    })

group_by_season.index = pd.Categorical(group_by_season.index, ["Spring", "Summer", "Fall", "Winter"])

group_by_season
# Out:
#         casual  registered  total_rentals
# Spring   60622      410726         471348
# Summer  203522      715067         918589
# Fall    226091      835038        1061129
# Winter  129782      711831         841613

# %% [markdown]
# ### Pertanyaan 2: Bagaimana jumlah pengguna sepeda dari tahun 2011-2012?

# %%
day_df['dteday'] = pd.to_datetime(day_df['dteday'])
date_user_df = day_df.resample('M', on='dteday').sum()[['casual', 'registered', 'total_rentals']]

date_user_df.index = date_user_df.index.strftime('%B')
date_user_df = date_user_df.reset_index()

date_user_df
# Out:
#        dteday  casual  registered  total_rentals
# 0     January    3073       35116          38189
# 1    February    6242       41973          48215
# 2       March   12826       51219          64045
# 3       April   22346       72524          94870
# 4         May   31050      104771         135821
# 5        June   30612      112900         143512
# 6        July   36452      104889         141341
# 7      August   28842      107849         136691
# 8   September   26545      100873         127418
# 9     October   25222       98289         123511
# 10   November   15594       86573         102167
# 11   December    8448       78875          87323
# 12    January    8969       87775          96744
# 13   February    8721       94416         103137
# 14      March   31618      133257         164875
# 15      April   38456      135768         174224
# 16        May   44235      151630         195865
# 17       June   43294      159536         202830
# ...

# %% [markdown]
# Memisahkan tahun 2011 dan 2012

# %%
filter_2011 = date_user_df.index <= 11

date_user_2011_df = date_user_df[filter_2011]

date_user_2011_df
# Out:
#        dteday  casual  registered  total_rentals
# 0     January    3073       35116          38189
# 1    February    6242       41973          48215
# 2       March   12826       51219          64045
# 3       April   22346       72524          94870
# 4         May   31050      104771         135821
# 5        June   30612      112900         143512
# 6        July   36452      104889         141341
# 7      August   28842      107849         136691
# 8   September   26545      100873         127418
# 9     October   25222       98289         123511
# 10   November   15594       86573         102167
# 11   December    8448       78875          87323

# %%
filter_2012 = date_user_df.index >= 12

date_user_2012_df = date_user_df[filter_2012]

date_user_2012_df
# Out:
#        dteday  casual  registered  total_rentals
# 12    January    8969       87775          96744
# 13   February    8721       94416         103137
# 14      March   31618      133257         164875
# 15      April   38456      135768         174224
# 16        May   44235      151630         195865
# 17       June   43294      159536         202830
# 18       July   41705      161902         203607
# 19     August   43197      171306         214503
# 20  September   43778      174795         218573
# 21    October   34538      164303         198841
# 22   November   21009      131655         152664
# 23   December   13245      110468         123713

# %% [markdown]
# ### Pertanyaan3: Kondisi cuaca apa biasanya orang lebih banyak melakukan sewa sepeda?

# %%
# Mengelompokkan jumlah data pengguna berdasarkan cuaca

group_by_weather = day_df.groupby(by='weathersit').agg({
    'casual': 'sum',
    'registered': 'sum',
    'total_rentals': 'sum',
    })

# group_by_weather.index = pd.Categorical(group_by_weather.index, ["Cerah/Berawan", "Berkabut", "Salju/Hujan Ringan"])

group_by_weather
# Out:
#             casual  registered  total_rentals
# weathersit
# 1           446346     1811606        2257952
# 2           169776      827082         996858
# 3             3895       33974          37869

# %% [markdown]
# ### Pertanyaan 4: Pada bulan apa pengguna paling banyak melakukan sewa sepeda di tahun 2011?

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Pada musim apa biasanya orang lebih banyak melakukan sewa sepeda?

# %%
colors = ["#D3D3D3", "#D3D3D3", "#72BCD4", "#D3D3D3",]

plt.figure(figsize=(8, 5))
sns.barplot(data=group_by_season, x=group_by_season.index, y='total_rentals', palette=colors)

plt.title("Jumlah Pengguna Berdasarkan Musim", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana jumlah pengguna sepeda dari tahun 2011-2012?

# %%
# Buat 2 kolom baru untuk mengelompokkan data berdasarkan jumlah pengguna dan tahun

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

ax[0].plot(date_user_2011_df['dteday'], date_user_2011_df['casual'], marker='o', linewidth=2, color="#72BCDA", label='Casual')
ax[0].plot(date_user_2011_df['dteday'], date_user_2011_df['registered'], marker='o', linewidth=2, color="#FD8A8A", label='Registered')
ax[0].plot(date_user_2011_df['dteday'], date_user_2011_df['total_rentals'], marker='o', linewidth=2, color="#829460", label='Total Rentals')
ax[0].set_xticklabels(date_user_2011_df['dteday'], rotation=30, ha='center')
ax[0].set_title("Tahun 2011", loc="center", fontsize=15)
ax[0].legend()

ax[1].plot(date_user_2012_df['dteday'], date_user_2012_df['casual'], marker='o', linewidth=2, color="#72BCDA", label='Casual')
ax[1].plot(date_user_2012_df['dteday'], date_user_2012_df['registered'], marker='o', linewidth=2, color="#FD8A8A", label='Registered')
ax[1].plot(date_user_2012_df['dteday'], date_user_2012_df['total_rentals'], marker='o', linewidth=2, color="#829460", label='Total Rentals')
ax[1].set_xticklabels(date_user_2012_df['dteday'], rotation=30, ha='center')
ax[1].set_title("Tahun 2012", loc="center", fontsize=15)
ax[1].legend()


plt.suptitle("Grafik Pengguna Sepeda Tahun 2011 dan 2012 Dalam Setahun", fontsize=20)
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17504\3599906416.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(date_user_2011_df['dteday'], rotation=30, ha='center')
# C:\Users\Acer\AppData\Local\Temp\ipykernel_17504\3599906416.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels(date_user_2012_df['dteday'], rotation=30, ha='center')

# %% [markdown]
# ### Pertanyaan3: Kondisi cuaca apa biasanya orang lebih banyak melakukan sewa sepeda?

# %%
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3"]

plt.figure(figsize=(8, 5))
sns.barplot(data=group_by_weather, x=["Cerah/Berawan", "Berkabut", "Salju/Hujan Ringan"], y='total_rentals', palette=colors)

plt.title("Jumlah Pengguna Berdasarkan Cuaca", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %% [markdown]
# ### Pertanyaan 4: Pada bulan apa pengguna paling banyak melakukan sewa sepeda di tahun 2011?

# %%
colors = ["#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", '#72BCD4',
"#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", '#D3D3D3',
          ]

plt.figure(figsize=(9, 6))
sns.barplot(data=date_user_2011_df, x=date_user_2011_df['dteday'], y='total_rentals', palette=colors)

plt.title("Jumlah Pengguna Pada Tahun 2011", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Pertanyaan 5: Pada bulan apa pengguna paling banyak melakukan sewa sepeda di tahun 2012?

# %%
colors = ["#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", '#D3D3D3',
"#D3D3D3", "#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3", '#D3D3D3',
          ]

plt.figure(figsize=(9, 6))
sns.barplot(data=date_user_2012_df, x=date_user_2012_df['dteday'], y='total_rentals', palette=colors)

plt.title("Jumlah Pengguna Pada Tahun 2012", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Berdasarkan hasil analisis untuk jawaban pertanyaan 1, didapatkan bahwa jumlah pengguna sepeda terbanyak adalah pada musim Fall
# - total pengguna pada tahun 2011 mengalami kenaikan dari bulan Januari hingga Juni. Penurunan jumlah pengguna terjadi dari bulan Juni hingga Desember.
#
# - total pengguna pada tahun 2012 mengalami kenaikan yang cukup drastis pada bulan Februari ke Maret dan cenderung naik hingga bulan September. Setelah bulan September, terjadi penurunah jumlah pengguna hingga bulan Desember.
#
# - Berdasarkan hasil analisis pada pertanyaan no 3, dapat diketahui untuk jumlah pengguna pada cuaca cerah/berawan unggul dari cuaca lain. Sedangkan pada cuaca salju/hujan ringan, jumlah pengguna sangat-sangat sedikit jika dibandingkan dengan cerah/berawan.
#
# - Berdasarkan hasil analisis pada pertanyaan no 4, dapat diketahui bahwa jumlah pengguna terbanyak pada tahun 2011 terdapat pada bulan Juni.
#
# - Berdasarkan hasil analisis pada pertanyaan no 5, dapat diketahui bahwa jumlah pengguna terbanyak pada tahun 2011 terdapat pada bulan September.
